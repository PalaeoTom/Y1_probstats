# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 2 (HT week 4)
#
# The problems in week 4 for Probability and Statistics focus on the probability of events, specifically how those probabilities can be mathematically represented as distributions. Use this empty notebook to complete portions of the lab that require the Math, NumPy, SciPy, Matplotlib, and other Python libraries. I've loaded a few libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# Solution to problem 1a here
# Here's a clue: the path includes "/data/data_week4/"

# %%
# Solution to problem 1b here

# %%
# Solutions to problem 1c here

# %%
# Solutions to problem 1d here

# %%
# Solutions to problems 1e/1f here

# %%
# Solutions to problem 2c here

# %%
# Solutions to problem 2d here

# %%
# Solutions to problem 2e here

# %%
# Solutions to problem 3a here

# %%
# Solutions to problem 3b here

# %%
# Solutions to problem 3c here

# %%
# Solution to problem 3d here
