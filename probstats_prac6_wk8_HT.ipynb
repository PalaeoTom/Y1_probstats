# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 6 (HT week 8)
#
# The problems in week 8 for Probability and Statistics focus on how we can statistically characterize relationships between variables using correlation and regression analysis. Use this empty notebook to complete portions of the lab that require the Math, NumPy, SciPy, Matplotlib, and other Python libraries. I've loaded a few libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt 
import statistics as st

# %%
# Solution for problem 1a here
# Path to data starts with in hub: "../data/data_week8/"

# %%
# Solution for problem 1b here

# %%
# Solution for problem 1c here

# %%
# Solution for problem 1d here

# %%
# Solution for problem 2a here
# Path to data starts with in hub: "../data/data_week8/"

# %%
# Solution for problem 2b here

# %%
# Solution for problem 2c here

# %%
# Solution for problem 2e here

# %%
# Solution for problem 2f here

# %%
# Solution for problem 2g here

# %%
# Solution for problem 3a here
# Path to data starts with in hub: "../data/data_week8/"

# %%
# Solution for problem 3b here

# %%
# Solution for problem 4b here

# %%
# Solution for problem 4c here

# %%
# Solution for problem 4d here

# %%
# Solution for problem 5a here

# %%
# Solution for problem 6a here

# %%
# Solution for problem 6b here

# %%
# Solution for problem 6c here
