# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 1 (HT week 3)
#
# The problems in week 3 for Probability and Statistics focus on the probability of events, specifically binomial probabilities. Use this empty notebook to complete portions of the Laboratory that require the Math, NumPy, SciPy, Matplotlib and other Python libraries. I've loaded these libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# Solution to problem 1e here

# %%
# Solution to problem 2c here

# %%
# Solution to problem 3a here

# %%
# Solution to problem 3b here

# %%
# Solution to problem 4a here

# %%
# Solution to problem 4b here

# %%
# Solution to problem 4c here
