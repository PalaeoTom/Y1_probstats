# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 4 (HT week 6)
#
# The problems in week 6 for Probability and Statistics focus on common statistical tests. Use this empty notebook to complete portions of the lab that require the Math, NumPy, SciPy, Matplotlib, and other Python libraries. I've loaded a few libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# Solution for problem 1a here

# %%
# Solution for problem 1b here

# %%
# Solution for problem 1c here

# %%
# Solution for problem 1d here

# %%
# Solutions for problems 2b-2f (first iteration) here
# 2b




# 2c




# 2d




# 2e




# 2f

# %%
# Solutions for problems 2b-f (second iteration) here
# 2b




# 2c




# 2d




# 2e




# 2f

# %%
# Solutions for problem 3a here

# %%
# Solutions for problem 3b here

# %%
# Solutions for problem 3c here
