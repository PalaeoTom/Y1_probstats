# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 2 (HT week 4)
#
# The problems in week 4 for Probability and Statistics focus on the probability of events, specifically how those probabilities can be mathematically represented as distributions. Use this empty notebook to complete portions of the lab that require the Math, NumPy, SciPy, Matplotlib, and other Python libraries. I've loaded a few libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m;
import numpy as np;
import scipy as sc;
import matplotlib.pyplot as plt;

# %%
# Solution to problem 1a here. The datafile has been provided to save you time. 
# A couple of hints: we're going to use a NumPy function here: loadtext. There are three parameters you should specify:
# 1) fname - this should be the path to the datafile in your working directory.
# 2) delimiter - HINT: its in the question.
# 3) dtype – HINT: what type of data is this?

# %%
# Solution to problem 1b here
# You could do this manually, but where is the beauty in that? My suggestion, think about how you might multiply all of values in one column
# of an array by another? Once you've done that, you can just add up the products of each row to get your answer. Again, we are looking at NumPy functions.

# %%
# Solutions to problem 1c here
# This is pretty straightforward. We will use MatPlotLib functions for this. Don't forget a title and axis labels!

# %%
# Solutions to problem 1d here. 
# What does our dataset capture? What else does the density parameter of this dataset represent?

# %%
# Solutions to problems 1e/1f here
# My suggestion: revisit the slides regarding the general expression for the Poisson distribution
# If you want to automate this in Python after calculating the expected frequency of a couple of the outcomes by hand,
# you'll need to use the NumPy functions to work over an array defined with np.arange(0,8)
# Alternatively, you can just calculate all of these expected frequencies by hand, manually define a new array of expected frequencies, and then plot using the same code you wrote for problem 1c.

# %%
# Solutions to problem 2c here. I've saved you the trouble of manually inputting the data. Now you do the rest!
ammonite_data = [1, 1, 1, 1, 1, 1, 2, 3, 6, 6, 1, 1, 2, 2, 1, 1, 4, 3, 2, 1, 1, 1, 1, 1, 1, 2, 1, 4]

# %%
# Solutions to problem 2d here. You're looking for a NumPy function here.

# %%
# Solutions to problem 2e here. You can load the data this time! Copy the formast from the solutions to problem 1c.
# Rinse and repeat what you have done above.

# %%
# Solutions to problem 3a here. Hint: think back to our first lecture...

# %%
# Solutions to problem 3b here. 
# Remember, sometimes it is easier to find to the probability of something not happening and subtract it from 1, rather than to calculate the probability itself.

# %%
# Solutions to problem 3c here
# Here's a hint: parameters p and n carry the same meaning as they do in our general expression for the binomial distribution.

# %%
# Solution to problem 3d here
# Same hint as above...
