# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 3 (HT week 5)
#
# The problems in week 5 for Probability and Statistics focus on exponential distributions and types of statistical errors. Use this empty notebook to complete portions of the lab that require the Math, NumPy, SciPy, Matplotlib, and other Python libraries. I've loaded a few libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# Solutions to problem 1d here.
# Think: what are you being asked to plot here?
# You know how much Yttrium decays in 24 hours. Start by working out how long it will take for you to reach 20% Yttrium left
# Then use this to define your x-axis. I'd recommend then using your x-axis increments in conjunction with the decay rate you derived in part (c)
# and the expression you derivied in part (b) to calculate your y-values. You'll need the NumPy functions to operate over arrays.

# %%
# Solutions to problem 2b here
# Remember, you'll need the NumPy functions to operate over arrays. You could calculate the probabilities manually but this would be
# too time consuming.

# %%
# Solutions to problem 2c here
# From a coding perspective, this is pretty straightforward. Use the array you define in part (b) to plot your histogram in conjunction with
# the function you identify. Feel free to plot the resulting CDF if that would make it easier to interpret!

# %%
# Solutions to problem 2e here
# Go back to the documentation and revisit the functions available, while thinking about what we are doing.
# We are excavating 20 samples from our established mine. We could think of this as drawing 20 values from our established distribution...

# %%
# Solution to problem 3a here
# Easy one to start here. Same type of function as 2(e), different distribution. Remember to check how the parameters change.
# When it comes to plotting, you will want to look at how to use the hist function from the matplotlib function.
# You'll need the probability of dextral specimens...make sure to define that first as p for simplicity (and for later on).

# %%
# Solutions to problem 3b here
# Copy and paste 3(a) with different numbers!

# %%
# Solution to problem 3c here
# Copy and paste 3(a) with different numbers!

# %%
# Solution to problem 3e here
# No coding tips needed here, except a remind that you can multiply each number in an array by numbers using the NumPy function.

# %%
# Solution to problem 3g here
# To produce the normal approximation, you'll need the norm function from SciPy. Specifically, the PDF function (as that is what we are plotting).
