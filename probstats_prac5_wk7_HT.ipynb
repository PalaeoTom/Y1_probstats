# %% [markdown]
# # Mathematics and Scientific Computing - Probability and Statistics problem sheet 5 (HT week 7)
#
# The problems in week 7 for Probability and Statistics focus ANOVA and the chi-square test. Use this empty notebook to complete portions of the lab that require the Math, NumPy, SciPy, Matplotlib, and other Python libraries. I've loaded a few libraries to get you started.
#
# If you want to answer all questions in the problem sheet in this document, simply add new markdown cells to the notebook. Make sure they are properly labelled to make life easy for your tutors!

# %%
# Import Math, NumPy, SciPy, and Matplotlib
import math as m
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
# Solutions for problem 1a here

# %%
# Solutions for problem 1b here

# %%
# Solution for problem 1c here

# %%
# Solution for problem 1d here

# %%
# Solution for problem 2 here

# %%
# Solution for problem 3a here

# %%
# Solution for problem 4a here
# Here's a clue: the path starts with ../data/data_week7/

# %%
# Solution for problem 4b here
